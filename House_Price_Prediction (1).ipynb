# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('drive/MyDrive/Colab Notebooks/csvdata/Housing (2).csv')
df.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
for i in df.columns:
  dis = len(df[i].unique())
  print(f"{i} - {dis}")
# Out:
# price - 219
# area - 284
# bedrooms - 6
# bathrooms - 4
# stories - 4
# mainroad - 2
# guestroom - 2
# basement - 2
# hotwaterheating - 2
# airconditioning - 2
# parking - 4
# prefarea - 2
# furnishingstatus - 3

# %%
df['parking'].value_counts()
# Out:
# 0    299
# 1    126
# 2    108
# 3     12
# Name: parking, dtype: int64

# %%
df['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder()
df['mainroad'] = enc.fit_transform(df[['mainroad']])
df['guestroom'] = enc.fit_transform(df[['guestroom']])
df['basement'] = enc.fit_transform(df[['basement']])
df['hotwaterheating'] = enc.fit_transform(df[['hotwaterheating']])
df['airconditioning'] = enc.fit_transform(df[['airconditioning']])
df['prefarea'] = enc.fit_transform(df[['prefarea']])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
# 1  12250000  8960         4          4        4       1.0        0.0
# 2  12250000  9960         3          2        2       1.0        0.0
# 3  12215000  7500         4          2        2       1.0        0.0
# 4  11410000  7420         4          1        2       1.0        1.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
# 1       0.0              0.0              1.0        3       0.0
# 2       1.0              0.0              0.0        2       1.0
# 3       1.0              0.0              1.0        3       1.0
# 4       1.0              0.0              1.0        2       0.0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
rank=['unfurnished','semi-furnished','furnished']
oe = OrdinalEncoder(categories=[rank])
df['furnishingstatus']=oe.fit_transform(df[['furnishingstatus']])
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
# 1  12250000  8960         4          4        4       1.0        0.0
# 2  12250000  9960         3          2        2       1.0        0.0
# 3  12215000  7500         4          2        2       1.0        0.0
# 4  11410000  7420         4          1        2       1.0        1.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
# 1       0.0              0.0              1.0        3       0.0
# 2       1.0              0.0              0.0        2       1.0
# 3       1.0              0.0              1.0        3       1.0
# 4       1.0              0.0              1.0        2       0.0
#
#    furnishingstatus
# 0               2.0
# 1               2.0
# 2               1.0
# 3               2.0
# 4               2.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['price'], bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['area'], bins=100)
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.scatterplot(x='price', y='area', hue='mainroad', data=df)
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.scatterplot(x='price', y='area', hue='guestroom', data=df)
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.scatterplot(x='price', y='area', hue='basement', data=df)
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.scatterplot(x='price', y='area', hue='hotwaterheating', data=df)
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.scatterplot(x='price', y='area', hue='airconditioning', data=df)
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.pairplot(vars=['area','bedrooms','bathrooms','stories','price'],data=df)

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='rocket_r', linewidths=0.5, fmt='.2f')
# Out:
# <Axes: >

# %%
X=df.drop(['price'],axis=1)
y=df['price']

# %%
X.shape
# Out:
# (545, 12)

# %%
y.shape
# Out:
# (545,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
X_train=scalar.fit_transform(X_train)
X_test=scalar.fit_transform(X_test)

# %%
X_train
# Out:
# array([[0.08955326, 0.4       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.25498282, 0.4       , 0.        , ..., 0.66666667, 1.        ,
#         0.        ],
#        [0.01278351, 0.2       , 0.        , ..., 0.        , 0.        ,
#         0.5       ],
#        ...,
#        [0.20274914, 0.2       , 0.33333333, ..., 0.66666667, 0.        ,
#         0.5       ],
#        [0.29896907, 0.6       , 0.33333333, ..., 0.        , 0.        ,
#         0.        ],
#        [0.13539519, 0.2       , 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
y_test
# Out:
# 231    4690000
# 305    4193000
# 404    3493000
# 506    2604000
# 484    2870000
#         ...
# 481    2940000
# 80     6629000
# 24     8575000
# 111    6090000
# 531    2233000
# Name: price, Length: 109, dtype: int64

# %%
y_pred
# Out:
# array([3635626.97779649, 3487194.38381736, 3063277.2657499 ,
#        1857970.1451908 , 1894088.30463888, 5684788.31017248,
#        3851783.52749413, 9177002.65901898, 4680427.02814783,
#        4629128.20830664, 3601455.63455004, 3843327.27867358,
#        4480624.66470277, 5677803.55994213, 4974918.54962861,
#        3756151.13498761, 8868569.11831463, 3751088.43871079,
#        4128852.69667752, 3630104.78806408, 2712775.46105918,
#        3134243.13617923, 6507559.81939487, 3365145.12222737,
#        7314741.31170653, 4210301.80906628, 3601117.62435594,
#        3309088.68934002, 3806101.25368193, 7191892.5677041 ,
#        6855988.51338649, 6795004.13486376, 5005775.01461642,
#        6232783.26748337, 8005811.16024572, 5851324.11387816,
#        5012459.31858693, 5950424.86442998, 5178901.85792417,
#        2932459.55424717, 5399990.27042935, 3945757.25826195,
#        2596379.43143268, 6989587.11636927, 5869176.21078101,
#        3283281.2755282 , 7552377.80383528, 2976952.53052405,
#        6311722.87801667, 7093069.42225741, 2440096.63683322,
#        5170122.75550366, 4519962.440479  , 2277062.96873991,
#        3755683.09001609, 6564141.71453063, 3827278.23758118,
#        6364702.81837521, 2496359.91296108, 5509339.65418103,
#        7525529.74083893, 3092557.94279713, 5782125.11032526,
#        7910634.89746094, 6032252.95245592, 2995513.56082505,
#        2616018.00356034, 3510210.02396668, 3234557.60010565,
#        4081271.11371666, 3403901.52018325, 2513111.64219941,
#        5680985.78430151, 5563858.9720926 , 6159633.95539551,
#        3160390.10825883, 2928766.37896447, 4325653.07102078,
#        7181324.20629507, 3471768.29006439, 3913303.09130878,
#        3333026.77592228, 4269472.34792938, 8259180.28935416,
#        4814374.74015515, 5378892.34952575, 4255402.53799608,
#        2876753.07364653, 6263407.41279462, 2655507.77305459,
#        5340902.01118733, 5718636.46483515, 6689032.37927082,
#        7552072.46436152, 7069377.13714552, 6630649.65137057,
#        5648316.42455257, 4885341.35825234, 3586320.41420879,
#        7438654.67771577, 4749061.01345769, 1882975.02480871,
#        7570987.90792246, 5245532.99156361, 2226402.67360044,
#        5596918.12224433, 7721853.78438105, 6181426.42331664,
#        4182532.9161044 ])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 1078944892449.7505

# %%
k=r2_score(y_pred,y_test)

# %%
k
# Out:
# 0.645333121801664

# %%
adj_r2= 1-(1-k)*(545-1)/(545-12-1)

# %%
adj_r2
# Out:
# 0.637333117030273

# %%
reg.score(X_test,y_test)
# Out:
# 0.7062957148332305

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')
